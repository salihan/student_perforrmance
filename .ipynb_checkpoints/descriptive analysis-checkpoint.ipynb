# %%
import pandas as pd

df = pd.read_csv('employee_data.csv')
df
# Out:
#    Employee_ID     Name  Age  Salary Department  Experience_Years
# 0            1    Alice   25  5000.0         HR                 2
# 1            2      Bob   30  6000.0         IT                10
# 2            3  Charlie   29     NaN         IT                 5
# 3            4    David   45  8000.0    Finance                25
# 4            5      Eve   29  7500.0         HR                50
# 5            6    Alice   25  5000.0         HR                 2
# 6            4    David   45  8000.0    Finance                25

# %%
y = df.iloc[:, 3].values
y
# Out:
# array([5000., 6000.,   nan, 8000., 7500., 5000., 8000.])

# %%
for i in range(10):
    print("HA!", end=" ")
# Out:
# HA! HA! HA! HA! HA! HA! HA! HA! HA! HA!
